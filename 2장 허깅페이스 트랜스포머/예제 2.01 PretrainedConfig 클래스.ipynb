# %%
# transformers 라이브러리가 설치안되어서 새로 설치함
from transformers import PretrainedConfig
# Gelu는 ReLU 대신에 쓰는 함수로 BERT에서 사용한다고 찾음
config = PretrainedConfig(
    model_type="bert",
    vocab_size=30522,
    hidden_size=768,
    num_attention_heads=12,
    num_hidden_layers=12,
    intermediate_size=3072,
    hidden_act="gelu",
    hidden_dropout_prob=0.1,
    initializer_range=0.02
)
print(config)
# Out:
# PreTrainedConfig {
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "transformers_version": "5.3.0",
#   "vocab_size": 30522
# }
